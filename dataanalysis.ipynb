# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv("olxcleaned.csv")

# %%
# Out:
#           Make    Model  Year  KM's driven    Price    Fuel Registration city  \
# 0       Toyota    Passo  2021        54000  4190000  Petrol      Unregistered
# 1       Suzuki     Ravi  2018        95000  1300000  Petrol           Karachi
# 2       Suzuki    Bolan  2015        50000   800000  Petrol           Karachi
# 3     Daihatsu     Move  2013        94000  2155000  Petrol            Lahore
# 4       Suzuki    Swift  2011       126544  1440000  Petrol           Karachi
# ...        ...      ...   ...          ...      ...     ...               ...
# 9174    Suzuki  Wagon R  2014       115000  2725000  Petrol         Islamabad
# 9175    Suzuki  Wagon R  2017       100000  1850000  Petrol            Lahore
# 9176       KIA  Spectra  2001       123456  1100000  Petrol            Lahore
# 9177    Suzuki     Alto  2009        89000   970000  Petrol            Lahore
# 9178  Daihatsu     Move  2016        95000  2050000  Petrol        Gujranwala
#
#      Car documents  Assembly Transmission Condition
# 0         Original  Imported    Automatic      Used
# 1         Original     Local       Manual      Used
# 2         Original     Local       Manual      Used
# 3         Original  Imported    Automatic      Used
# 4         Original     Local       Manual      Used
# ...            ...       ...          ...       ...
# 9174      Original  Imported    Automatic      Used
# 9175      Original     Local       Manual      Used
# 9176      Original  Imported    Automatic      Used
# 9177      Original  Imported       Manual      Used
# 9178      Original  Imported    Automatic      Used
#
# [9179 rows x 11 columns]

# %%
df['Transmission'].unique()
# Out:
# array(['Automatic', 'Manual'], dtype=object)

# %%
# Machine Learning Model
# y = "Price"
#x = ?
# we have to create a regression model

# %%
lb = LabelEncoder()
feature = {}
for k in df.columns:
    if df[k].dtypes=='O':
        df[str(k)+'_Encode'] = lb.fit_transform(df[k])
        gt = {}
        ke = df[[k,str(k)+'_Encode']].drop_duplicates()[str(k)+'_Encode'].values
        val = df[[k,str(k)+'_Encode']].drop_duplicates()[k].values
        for i in range(len(ke)):
            gt[val[i]] = str(ke[i])
        feature[k] = gt

# %%
feature
# Out:
# {'Make': {'Toyota': '10',
#   'Suzuki': '9',
#   'Daihatsu': '2',
#   'Honda': '4',
#   'Hyundai': '5',
#   'Mitsubishi': '8',
#   'KIA': '6',
#   'Changan': '0',
#   'FAW': '3',
#   'Mercedes': '7',
#   'Chevrolet': '1'},
#  'Model': {'Passo': '44',
#   'Ravi': '47',
#   'Bolan': '4',
#   'Move': '42',
#   'Swift': '52',
#   'Wagon R': '55',
#   'Mira': '41',
#   'City IDSI': '8',
#   'Cultus VXR': '23',
#   'Every': '27',
#   'Corolla XLI': '20',
#   'Baleno': '3',
#   'City Vario': '10',
#   'Terios Kid': '53',
#   'Civic Prosmetic': '13',
#   'City IVTEC': '9',
#   'Santro': '48',
#   'Corrolla Altis': '21',
#   'City Aspire': '7',
#   'Mehran VXR': '38',
#   'Cuore': '24',
#   'Pajero Mini': '43',
#   'Picanto': '45',
#   'Alto': '2',
#   'Karvaan': '33',
#   'X-PV': '56',
#   'Hijet': '30',
#   'Ek Wagon': '26',
#   'Altis Grande': '1',
#   'E Class': '25',
#   'Yaris': '57',
#   'Lancer': '35',
#   'Corolla GLI': '19',
#   'Joy': '32',
#   'Civic Oriel': '12',
#   'Classic': '16',
#   'Spectra': '49',
#   'V2': '54',
#   'Minicab Bravo': '40',
#   'Corolla Assista': '17',
#   'Alsvin': '0',
#   'C Class': '5',
#   'Minica': '39',
#   'Exclusive': '29',
#   'Civic VTi': '14',
#   'Cervo': '6',
#   'Sportage': '50',
#   'Corolla Axio': '18',
#   'Every Wagon': '28',
#   'Liana': '36',
#   'Civic EXi': '11',
#   'Surf': '51',
#   'Mehran VX': '37',
#   'Civic VTi Oriel': '15',
#   'Khyber': '34',
#   'Cultus VXL': '22',
#   'Prius': '46',
#   'ISIS': '31'},
#  'Fuel': {'Petrol': '3', 'CNG': '0', 'Hybrid': '2', 'Diesel': '1'},
#  'Registration city': {'Unregistered': '57',
#   'Karachi': '25',
#   'Lahore': '30',
#   'Sindh': '51',
#   'Faisalabad': '15',
#   'Islamabad': '21',
#   'Sialkot': '50',
#   'Gujranwala': '16',
#   'Punjab': '43',
#   'Multan': '37',
#   'Rawalpindi': '46',
#   'Bahawalpur': '5',
#   'Hyderabad': '20',
#   'Rahimyar Khan': '45',
#   'Chishtian Mandi': '11',
#   'Chiniot': '10',
#   'Wazirabad': '60',
#   'Sahiwal': '47',
#   'Gujrat': '17',
#   'Abbottabad': '0',
#   'Khanewal': '27',
#   'Peshawar': '41',
#   'Sargodha': '48',
#   'Bannu': '6',
#   'Nowshera': '39',
#   'Kasur': '26',
#   'Arifwala': '1',
#   'Jhang Sadar': '23',
#   'Dera Ghazi Khan': '13',
#   'Mardan': '33',
#   'Attock': '2',
#   'Larkana': '31',
#   'Unknown': '56',
#   'Jhelum': '24',
#   'Khanpur': '28',
#   'Wah': '59',
#   'Okara': '40',
#   'Bhakkar': '7',
#   'Sheikhüpura': '49',
#   'Swat': '54',
#   'Dera Ismail Khan': '14',
#   'Khushab': '29',
#   'Bhimber': '8',
#   'Mansehra': '32',
#   'Mirpur': '35',
#   'Quetta': '44',
#   'Vehari': '58',
#   'Hafizabad': '18',
#   'Charsadda': '9',
#   'Toba Tek singh': '55',
#   'Jaranwala': '22',
#   'Pirmahal': '42',
#   'Haripur': '19',
#   'Mirpur Khas': '36',
#   'Bahawalnagar': '4',
#   'Swabi': '53',
#   'Dadu': '12',
#   'Mianwali': '34',
#   'Sukkar': '52',
#   'Badin': '3',
#   'Nawabshah': '38'},
#  'Car documents': {'Original': '1', 'Duplicate': '0'},
#  'Assembly': {'Imported': '0', 'Local': '1'},
#  'Transmission': {'Automatic': '0', 'Manual': '1'},
#  'Condition': {'Used': '0'}}

# %%
df
# Out:
#           Make    Model  Year  KM's driven    Price    Fuel Registration city  \
# 0       Toyota    Passo  2021        54000  4190000  Petrol      Unregistered
# 1       Suzuki     Ravi  2018        95000  1300000  Petrol           Karachi
# 2       Suzuki    Bolan  2015        50000   800000  Petrol           Karachi
# 3     Daihatsu     Move  2013        94000  2155000  Petrol            Lahore
# 4       Suzuki    Swift  2011       126544  1440000  Petrol           Karachi
# ...        ...      ...   ...          ...      ...     ...               ...
# 9174    Suzuki  Wagon R  2014       115000  2725000  Petrol         Islamabad
# 9175    Suzuki  Wagon R  2017       100000  1850000  Petrol            Lahore
# 9176       KIA  Spectra  2001       123456  1100000  Petrol            Lahore
# 9177    Suzuki     Alto  2009        89000   970000  Petrol            Lahore
# 9178  Daihatsu     Move  2016        95000  2050000  Petrol        Gujranwala
#
#      Car documents  Assembly Transmission Condition  Make_Encode  \
# 0         Original  Imported    Automatic      Used           10
# 1         Original     Local       Manual      Used            9
# 2         Original     Local       Manual      Used            9
# 3         Original  Imported    Automatic      Used            2
# 4         Original     Local       Manual      Used            9
# ...            ...       ...          ...       ...          ...
# 9174      Original  Imported    Automatic      Used            9
# 9175      Original     Local       Manual      Used            9
# 9176      Original  Imported    Automatic      Used            6
# 9177      Original  Imported       Manual      Used            9
# 9178      Original  Imported    Automatic      Used            2
#
#       Model_Encode  Fuel_Encode  Registration city_Encode  \
# 0               44            3                        57
# 1               47            3                        25
# 2                4            3                        25
# 3               42            3                        30
# 4               52            3                        25
# ...            ...          ...                       ...
# 9174            55            3                        21
# 9175            55            3                        30
# 9176            49            3                        30
# 9177             2            3                        30
# 9178            42            3                        16
#
#       Car documents_Encode  Assembly_Encode  Transmission_Encode  \
# 0                        1                0                    0
# 1                        1                1                    1
# 2                        1                1                    1
# 3                        1                0                    0
# 4                        1                1                    1
# ...                    ...              ...                  ...
# 9174                     1                0                    0
# 9175                     1                1                    1
# 9176                     1                0                    0
# 9177                     1                0                    1
# 9178                     1                0                    0
#
#       Condition_Encode
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0
# ...                ...
# 9174                 0
# 9175                 0
# 9176                 0
# 9177                 0
# 9178                 0
#
# [9179 rows x 19 columns]

# %%
feature
# Out:
# {'Make': {'Toyota': '10',
#   'Suzuki': '9',
#   'Daihatsu': '2',
#   'Honda': '4',
#   'Hyundai': '5',
#   'Mitsubishi': '8',
#   'KIA': '6',
#   'Changan': '0',
#   'FAW': '3',
#   'Mercedes': '7',
#   'Chevrolet': '1'},
#  'Model': {'Passo': '44',
#   'Ravi': '47',
#   'Bolan': '4',
#   'Move': '42',
#   'Swift': '52',
#   'Wagon R': '55',
#   'Mira': '41',
#   'City IDSI': '8',
#   'Cultus VXR': '23',
#   'Every': '27',
#   'Corolla XLI': '20',
#   'Baleno': '3',
#   'City Vario': '10',
#   'Terios Kid': '53',
#   'Civic Prosmetic': '13',
#   'City IVTEC': '9',
#   'Santro': '48',
#   'Corrolla Altis': '21',
#   'City Aspire': '7',
#   'Mehran VXR': '38',
#   'Cuore': '24',
#   'Pajero Mini': '43',
#   'Picanto': '45',
#   'Alto': '2',
#   'Karvaan': '33',
#   'X-PV': '56',
#   'Hijet': '30',
#   'Ek Wagon': '26',
#   'Altis Grande': '1',
#   'E Class': '25',
#   'Yaris': '57',
#   'Lancer': '35',
#   'Corolla GLI': '19',
#   'Joy': '32',
#   'Civic Oriel': '12',
#   'Classic': '16',
#   'Spectra': '49',
#   'V2': '54',
#   'Minicab Bravo': '40',
#   'Corolla Assista': '17',
#   'Alsvin': '0',
#   'C Class': '5',
#   'Minica': '39',
#   'Exclusive': '29',
#   'Civic VTi': '14',
#   'Cervo': '6',
#   'Sportage': '50',
#   'Corolla Axio': '18',
#   'Every Wagon': '28',
#   'Liana': '36',
#   'Civic EXi': '11',
#   'Surf': '51',
#   'Mehran VX': '37',
#   'Civic VTi Oriel': '15',
#   'Khyber': '34',
#   'Cultus VXL': '22',
#   'Prius': '46',
#   'ISIS': '31'},
#  'Fuel': {'Petrol': '3', 'CNG': '0', 'Hybrid': '2', 'Diesel': '1'},
#  'Registration city': {'Unregistered': '57',
#   'Karachi': '25',
#   'Lahore': '30',
#   'Sindh': '51',
#   'Faisalabad': '15',
#   'Islamabad': '21',
#   'Sialkot': '50',
#   'Gujranwala': '16',
#   'Punjab': '43',
#   'Multan': '37',
#   'Rawalpindi': '46',
#   'Bahawalpur': '5',
#   'Hyderabad': '20',
#   'Rahimyar Khan': '45',
#   'Chishtian Mandi': '11',
#   'Chiniot': '10',
#   'Wazirabad': '60',
#   'Sahiwal': '47',
#   'Gujrat': '17',
#   'Abbottabad': '0',
#   'Khanewal': '27',
#   'Peshawar': '41',
#   'Sargodha': '48',
#   'Bannu': '6',
#   'Nowshera': '39',
#   'Kasur': '26',
#   'Arifwala': '1',
#   'Jhang Sadar': '23',
#   'Dera Ghazi Khan': '13',
#   'Mardan': '33',
#   'Attock': '2',
#   'Larkana': '31',
#   'Unknown': '56',
#   'Jhelum': '24',
#   'Khanpur': '28',
#   'Wah': '59',
#   'Okara': '40',
#   'Bhakkar': '7',
#   'Sheikhüpura': '49',
#   'Swat': '54',
#   'Dera Ismail Khan': '14',
#   'Khushab': '29',
#   'Bhimber': '8',
#   'Mansehra': '32',
#   'Mirpur': '35',
#   'Quetta': '44',
#   'Vehari': '58',
#   'Hafizabad': '18',
#   'Charsadda': '9',
#   'Toba Tek singh': '55',
#   'Jaranwala': '22',
#   'Pirmahal': '42',
#   'Haripur': '19',
#   'Mirpur Khas': '36',
#   'Bahawalnagar': '4',
#   'Swabi': '53',
#   'Dadu': '12',
#   'Mianwali': '34',
#   'Sukkar': '52',
#   'Badin': '3',
#   'Nawabshah': '38'},
#  'Car documents': {'Original': '1', 'Duplicate': '0'},
#  'Assembly': {'Imported': '0', 'Local': '1'},
#  'Transmission': {'Automatic': '0', 'Manual': '1'},
#  'Condition': {'Used': '0'}}

# %%
import json
with open('encdata.json','w') as jsonfile:
    json.dump(feature,jsonfile,indent=4)

# %%
df
# Out:
#           Make    Model  Year  KM's driven    Price    Fuel Registration city  \
# 0       Toyota    Passo  2021        54000  4190000  Petrol      Unregistered
# 1       Suzuki     Ravi  2018        95000  1300000  Petrol           Karachi
# 2       Suzuki    Bolan  2015        50000   800000  Petrol           Karachi
# 3     Daihatsu     Move  2013        94000  2155000  Petrol            Lahore
# 4       Suzuki    Swift  2011       126544  1440000  Petrol           Karachi
# ...        ...      ...   ...          ...      ...     ...               ...
# 9174    Suzuki  Wagon R  2014       115000  2725000  Petrol         Islamabad
# 9175    Suzuki  Wagon R  2017       100000  1850000  Petrol            Lahore
# 9176       KIA  Spectra  2001       123456  1100000  Petrol            Lahore
# 9177    Suzuki     Alto  2009        89000   970000  Petrol            Lahore
# 9178  Daihatsu     Move  2016        95000  2050000  Petrol        Gujranwala
#
#      Car documents  Assembly Transmission Condition  Make_Encode  \
# 0         Original  Imported    Automatic      Used           10
# 1         Original     Local       Manual      Used            9
# 2         Original     Local       Manual      Used            9
# 3         Original  Imported    Automatic      Used            2
# 4         Original     Local       Manual      Used            9
# ...            ...       ...          ...       ...          ...
# 9174      Original  Imported    Automatic      Used            9
# 9175      Original     Local       Manual      Used            9
# 9176      Original  Imported    Automatic      Used            6
# 9177      Original  Imported       Manual      Used            9
# 9178      Original  Imported    Automatic      Used            2
#
#       Model_Encode  Fuel_Encode  Registration city_Encode  \
# 0               44            3                        57
# 1               47            3                        25
# 2                4            3                        25
# 3               42            3                        30
# 4               52            3                        25
# ...            ...          ...                       ...
# 9174            55            3                        21
# 9175            55            3                        30
# 9176            49            3                        30
# 9177             2            3                        30
# 9178            42            3                        16
#
#       Car documents_Encode  Assembly_Encode  Transmission_Encode  \
# 0                        1                0                    0
# 1                        1                1                    1
# 2                        1                1                    1
# 3                        1                0                    0
# 4                        1                1                    1
# ...                    ...              ...                  ...
# 9174                     1                0                    0
# 9175                     1                1                    1
# 9176                     1                0                    0
# 9177                     1                0                    1
# 9178                     1                0                    0
#
#       Condition_Encode
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0
# ...                ...
# 9174                 0
# 9175                 0
# 9176                 0
# 9177                 0
# 9178                 0
#
# [9179 rows x 19 columns]

# %%
df.drop(["Make","Model","Fuel","Registration city","Car documents","Assembly","Transmission","Condition"],axis = 1,inplace = True)

# %%
df.corr()
# Out:
#                               Year  KM's driven     Price  Make_Encode  \
# Year                      1.000000    -0.380755  0.680901     0.114643
# KM's driven              -0.380755     1.000000 -0.188484    -0.023023
# Price                     0.680901    -0.188484  1.000000     0.065637
# Make_Encode               0.114643    -0.023023  0.065637     1.000000
# Model_Encode              0.102776    -0.082881 -0.057632     0.009927
# Fuel_Encode               0.131813    -0.013172  0.130603    -0.048755
# Registration city_Encode  0.043368    -0.017700  0.020011    -0.015363
# Car documents_Encode      0.054928    -0.025006  0.055482     0.002732
# Assembly_Encode           0.147155    -0.043671  0.132720     0.225670
# Transmission_Encode      -0.189711     0.048803 -0.461263     0.165784
# Condition_Encode               NaN          NaN       NaN          NaN
#
#                           Model_Encode  Fuel_Encode  Registration city_Encode  \
# Year                          0.102776     0.131813                  0.043368
# KM's driven                  -0.082881    -0.013172                 -0.017700
# Price                        -0.057632     0.130603                  0.020011
# Make_Encode                   0.009927    -0.048755                 -0.015363
# Model_Encode                  1.000000     0.038281                  0.019549
# Fuel_Encode                   0.038281     1.000000                 -0.019498
# Registration city_Encode      0.019549    -0.019498                  1.000000
# Car documents_Encode         -0.006628     0.013820                  0.010902
# Assembly_Encode              -0.207514    -0.006709                 -0.041725
# Transmission_Encode          -0.032439    -0.099590                  0.006332
# Condition_Encode                   NaN          NaN                       NaN
#
#                           Car documents_Encode  Assembly_Encode  \
# Year                                  0.054928         0.147155
# KM's driven                          -0.025006        -0.043671
# Price                                 0.055482         0.132720
# Make_Encode                           0.002732         0.225670
# Model_Encode                         -0.006628        -0.207514
# Fuel_Encode                           0.013820        -0.006709
# Registration city_Encode              0.010902        -0.041725
# Car documents_Encode                  1.000000         0.003850
# Assembly_Encode                       0.003850         1.000000
# Transmission_Encode                  -0.013750         0.264036
# Condition_Encode                           NaN              NaN
#
#                           Transmission_Encode  Condition_Encode
# Year                                -0.189711               NaN
# KM's driven                          0.048803               NaN
# Price                               -0.461263               NaN
# Make_Encode                          0.165784               NaN
# Model_Encode                        -0.032439               NaN
# Fuel_Encode                         -0.099590               NaN
# Registration city_Encode             0.006332               NaN
# Car documents_Encode                -0.013750               NaN
# Assembly_Encode                      0.264036               NaN
# Transmission_Encode                  1.000000               NaN
# Condition_Encode                          NaN               NaN

# %%
y = df['Price']
X = df.drop(['Price','Condition_Encode'],axis = 1)

# %%
X
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 X
#
# NameError: name 'X' is not defined

# %%
y
# Out:
# 0       4190000
# 1       1300000
# 2        800000
# 3       2155000
# 4       1440000
#          ...
# 9174    2725000
# 9175    1850000
# 9176    1100000
# 9177     970000
# 9178    2050000
# Name: Price, Length: 9179, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25,random_state=2529)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(X_test,y_test)
# Out:
# 0.592044180895434

# %%
X
# Out:
#       Year  KM's driven  Make_Encode  Model_Encode  Fuel_Encode  \
# 0     2021        54000           10            44            3
# 1     2018        95000            9            47            3
# 2     2015        50000            9             4            3
# 3     2013        94000            2            42            3
# 4     2011       126544            9            52            3
# ...    ...          ...          ...           ...          ...
# 9174  2014       115000            9            55            3
# 9175  2017       100000            9            55            3
# 9176  2001       123456            6            49            3
# 9177  2009        89000            9             2            3
# 9178  2016        95000            2            42            3
#
#       Registration city_Encode  Car documents_Encode  Assembly_Encode  \
# 0                           57                     1                0
# 1                           25                     1                1
# 2                           25                     1                1
# 3                           30                     1                0
# 4                           25                     1                1
# ...                        ...                   ...              ...
# 9174                        21                     1                0
# 9175                        30                     1                1
# 9176                        30                     1                0
# 9177                        30                     1                0
# 9178                        16                     1                0
#
#       Transmission_Encode
# 0                       0
# 1                       1
# 2                       1
# 3                       0
# 4                       1
# ...                   ...
# 9174                    0
# 9175                    1
# 9176                    0
# 9177                    1
# 9178                    0
#
# [9179 rows x 9 columns]

# %%
lr.predict([[ 2021, 54000,    10,    44,     3,    57,     1,     0,     0]])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([3342070.46511096])

# %%
import pickle
with open('model.pickle','wb') as model_file:
    pickle.dump(lr,model_file)
